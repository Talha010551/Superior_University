# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# #  DATA LOADING

# %%
df= pd.read_csv('laptop_cleaned2.csv')
df
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %% [markdown]
# # Data Exploration

# %%
print(f"Number of Rows: {df.shape[0]}\nNumber of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 1020
# Number of Columns: 29

# %%
df.head(2)
# Out:
#    Unnamed: 0                                               Name   Brand  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...      HP
# 1           1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...  Lenovo
#
#    Price  Rating Processor_brand Processor_name Processor_variant  \
# 0  50399    4.30             AMD    AMD Ryzen 5             5600H
# 1  26690    4.45             AMD    AMD Ryzen 3             7320U
#
#    Processor_gen  Core_per_processor  ...        Graphics_name  \
# 0            5.0                 6.0  ...  AMD Radeon RX 6500M
# 1            7.0                 4.0  ...  AMD Radeon Graphics
#
#    Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# 0             AMD          4.0                False                 15.6
# 1             AMD          NaN                False                 15.6
#
#    Horizontal_pixel Vertical_pixel     ppi Touch_screen Operating_system
# ...

# %%
df.tail(2)
# Out:
#       Unnamed: 0                                               Name Brand  \
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...  Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...  Dell
#
#       Price  Rating Processor_brand Processor_name Processor_variant  \
# 1018  54999    4.25             AMD    AMD Ryzen 5             7530U
# 1019  94490    4.05           Intel  Intel Core i5             1335U
#
#       Processor_gen  Core_per_processor  ...           Graphics_name  \
# 1018            7.0                 6.0  ...          AMD Radeon AMD
# 1019           13.0                10.0  ...  Intel Iris Xe Graphics
#
#       Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# 1018             AMD          NaN                False                 16.0
# 1019           Intel          NaN                False                 16.0
#
#       Horizontal_pixel Vertical_pixel     ppi Touch_screen Operating_system
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0          Price       Rating  Processor_gen  \
# count  1020.000000    1020.000000  1020.000000     891.000000
# mean    509.500000   82063.474510     4.373676      10.450056
# std     294.592939   66502.150607     0.233295       2.966579
# min       0.000000    8000.000000     3.950000       1.000000
# 25%     254.750000   43990.000000     4.200000       7.000000
# 50%     509.500000   63689.500000     4.350000      12.000000
# 75%     764.250000   94990.000000     4.550000      13.000000
# max    1019.000000  599990.000000     4.750000      14.000000
#
#        Core_per_processor  Total_processor  Execution_units  Low_Power_Cores  \
# count         1008.000000       573.000000       573.000000      1020.000000
# mean             8.572421         3.926702         6.998255         0.086275
# std              4.375012         1.954429         2.680217         0.406531
# min              2.000000         1.000000         4.000000         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1020 non-null   int64
#  1   Name                    1020 non-null   object
#  2   Brand                   1020 non-null   object
#  3   Price                   1020 non-null   int64
#  4   Rating                  1020 non-null   float64
#  5   Processor_brand         1020 non-null   object
#  6   Processor_name          1020 non-null   object
#  7   Processor_variant       996 non-null    object
#  8   Processor_gen           891 non-null    float64
#  9   Core_per_processor      1008 non-null   float64
#  10  Total_processor         573 non-null    float64
#  11  Execution_units         573 non-null    float64
#  12  Low_Power_Cores         1020 non-null   float64
#  13  Energy_Efficient_Units  1020 non-null   int64
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# Unnamed: 0
# Name
# Brand
# Price
# Rating
# Processor_brand
# Processor_name
# Processor_variant
# Processor_gen
# Core_per_processor
# Total_processor
# Execution_units
# Low_Power_Cores
# Energy_Efficient_Units
# Threads
# RAM_GB
# RAM_type
# Storage_capacity_GB
# Storage_type
# Graphics_name
# Graphics_brand
# Graphics_GB
# Graphics_integreted
# Display_size_inches
# Horizontal_pixel
# Vertical_pixel
# ppi
# Touch_screen
# Operating_system

# %%
df.count()
# Out:
# Unnamed: 0                1020
# Name                      1020
# Brand                     1020
# Price                     1020
# Rating                    1020
# Processor_brand           1020
# Processor_name            1020
# Processor_variant          996
# Processor_gen              891
# Core_per_processor        1008
# Total_processor            573
# Execution_units            573
# Low_Power_Cores           1020
# Energy_Efficient_Units    1020
# Threads                    972
# RAM_GB                    1020
# RAM_type                   998
# Storage_capacity_GB       1020
# Storage_type              1020
# Graphics_name             1018
# Graphics_brand            1018
# Graphics_GB                368
# Graphics_integreted       1018
# Display_size_inches       1020
# Horizontal_pixel          1020
# Vertical_pixel            1020
# ppi                       1020
# Touch_screen              1020
# Operating_system          1020
# dtype: int64

# %%
df['Brand'].unique()
# Out:
# array(['HP', 'Lenovo', 'Samsung', 'Tecno', 'Xiaomi', 'Dell', 'Asus',
#        'Wings', 'Apple', 'Zebronics', 'Gigabyte', 'Acer', 'MSI',
#        'Infinix', 'Honor', 'Colorful', 'iBall', 'Walker', 'Chuwi', 'ASUS',
#        'Ultimus', 'Jio', 'Microsoft', 'Primebook', 'Ninkear', 'Avita',
#        'Huawei', 'Fujitsu', 'LG', 'Razer', 'AXL'], dtype=object)

# %%
df.nunique()
# Out:
# Unnamed: 0                1020
# Name                      1020
# Brand                       31
# Price                      561
# Rating                      17
# Processor_brand              7
# Processor_name              36
# Processor_variant          125
# Processor_gen               13
# Core_per_processor          12
# Total_processor              8
# Execution_units              5
# Low_Power_Cores              2
# Energy_Efficient_Units       2
# Threads                     14
# RAM_GB                      10
# RAM_type                    12
# Storage_capacity_GB         10
# Storage_type                 4
# Graphics_name              136
# Graphics_brand               7
# Graphics_GB                  6
# Graphics_integreted          2
# Display_size_inches         22
# Horizontal_pixel            22
# Vertical_pixel              22
# ppi                         62
# Touch_screen                 2
# Operating_system            13
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Name                        0
# Brand                       0
# Price                       0
# Rating                      0
# Processor_brand             0
# Processor_name              0
# Processor_variant          24
# Processor_gen             129
# Core_per_processor         12
# Total_processor           447
# Execution_units           447
# Low_Power_Cores             0
# Energy_Efficient_Units      0
# Threads                    48
# RAM_GB                      0
# RAM_type                   22
# Storage_capacity_GB         0
# Storage_type                0
# Graphics_name               2
# Graphics_brand              2
# Graphics_GB               652
# Graphics_integreted         2
# Display_size_inches         0
# Horizontal_pixel            0
# Vertical_pixel              0
# ppi                         0
# Touch_screen                0
# Operating_system            0
# dtype: int64

# %% [markdown]
# # Data Pre-Processing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1020 non-null   int64
#  1   Name                    1020 non-null   object
#  2   Brand                   1020 non-null   object
#  3   Price                   1020 non-null   int64
#  4   Rating                  1020 non-null   float64
#  5   Processor_brand         1020 non-null   object
#  6   Processor_name          1020 non-null   object
#  7   Processor_variant       996 non-null    object
#  8   Processor_gen           891 non-null    float64
#  9   Core_per_processor      1008 non-null   float64
#  10  Total_processor         573 non-null    float64
#  11  Execution_units         573 non-null    float64
#  12  Low_Power_Cores         1020 non-null   float64
#  13  Energy_Efficient_Units  1020 non-null   int64
# ...

# %% [markdown]
# ## Dealing with null values

# %%
def fillNaMean(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mean())

columns = ['Rating', 'Processor_gen', 'Core_per_processor', 'Total_processor', 'Execution_units', 'Low_Power_Cores', 'Threads', 'Graphics_GB', 'Display_size_inches', 'ppi']
fillNaMean(columns)

# %%
def fillNaMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['Name', 'Brand', 'Processor_brand', 'Processor_brand', 'Processor_variant', 'RAM_type', 'Storage_type', 'Graphics_name', 'Graphics_brand', 'Graphics_integreted', 'Operating_system']
fillNaMode(columns)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# Brand                     0
# Price                     0
# Rating                    0
# Processor_brand           0
# Processor_name            0
# Processor_variant         0
# Processor_gen             0
# Core_per_processor        0
# Total_processor           0
# Execution_units           0
# Low_Power_Cores           0
# Energy_Efficient_Units    0
# Threads                   0
# RAM_GB                    0
# RAM_type                  0
# Storage_capacity_GB       0
# Storage_type              0
# Graphics_name             0
# Graphics_brand            0
# Graphics_GB               0
# Graphics_integreted       0
# Display_size_inches       0
# Horizontal_pixel          0
# Vertical_pixel            0
# ppi                       0
# Touch_screen              0
# Operating_system          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1020 non-null   int64
#  1   Name                    1020 non-null   object
#  2   Brand                   1020 non-null   object
#  3   Price                   1020 non-null   int64
#  4   Rating                  1020 non-null   float64
#  5   Processor_brand         1020 non-null   object
#  6   Processor_name          1020 non-null   object
#  7   Processor_variant       1020 non-null   object
#  8   Processor_gen           1020 non-null   float64
#  9   Core_per_processor      1020 non-null   float64
#  10  Total_processor         1020 non-null   float64
#  11  Execution_units         1020 non-null   float64
#  12  Low_Power_Cores         1020 non-null   float64
#  13  Energy_Efficient_Units  1020 non-null   int64
# ...

# %% [markdown]
# ## Dropping Irrelevant Columns

# %%
df.drop('Graphics_integreted', axis=1, inplace=True)
df.drop('Rating', axis=1, inplace=True)
df.drop('Core_per_processor', axis=1, inplace=True)
df.drop('Total_processor', axis=1, inplace=True)
df.drop('Execution_units', axis=1, inplace=True)
df.drop('Low_Power_Cores', axis=1, inplace=True)
df.drop('Energy_Efficient_Units', axis=1, inplace=True)
df.drop('Threads', axis=1, inplace=True)
df.drop('Horizontal_pixel', axis=1, inplace=True)
df.drop('Vertical_pixel', axis=1, inplace=True)
df.drop('ppi', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1020 non-null   int64
#  1   Name                 1020 non-null   object
#  2   Brand                1020 non-null   object
#  3   Price                1020 non-null   int64
#  4   Processor_brand      1020 non-null   object
#  5   Processor_name       1020 non-null   object
#  6   Processor_variant    1020 non-null   object
#  7   Processor_gen        1020 non-null   float64
#  8   RAM_GB               1020 non-null   int64
#  9   RAM_type             1020 non-null   object
#  10  Storage_capacity_GB  1020 non-null   int64
#  11  Storage_type         1020 non-null   object
#  12  Graphics_name        1020 non-null   object
#  13  Graphics_brand       1020 non-null   object
#  14  Graphics_GB          1020 non-null   float64
# ...

# %%
def changeFloattoInt64(cols):
    for i in cols:
        df[i] = df[i].astype('int64')

columns = ['Processor_gen', 'Graphics_GB', 'Display_size_inches','Touch_screen']
changeFloattoInt64(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1020 non-null   int64
#  1   Name                 1020 non-null   object
#  2   Brand                1020 non-null   object
#  3   Price                1020 non-null   int64
#  4   Processor_brand      1020 non-null   object
#  5   Processor_name       1020 non-null   object
#  6   Processor_variant    1020 non-null   object
#  7   Processor_gen        1020 non-null   int64
#  8   RAM_GB               1020 non-null   int64
#  9   RAM_type             1020 non-null   object
#  10  Storage_capacity_GB  1020 non-null   int64
#  11  Storage_type         1020 non-null   object
#  12  Graphics_name        1020 non-null   object
#  13  Graphics_brand       1020 non-null   object
#  14  Graphics_GB          1020 non-null   int64
# ...

# %%
df_clean = df.copy()

# %%
def encodeCols(cols):
    for i in cols:
        temp = pd.DataFrame({i:df[i].unique()})
        data_LE = LabelEncoder()
        data_LE.fit(np.ravel(temp))

        df_clean[i] = data_LE.transform(df[i])

columns = ['Name', 'Brand', 'Processor_brand', 'Processor_name', 'Processor_variant', 'RAM_type', 'Storage_type', 'Graphics_name', 'Graphics_brand', 'Operating_system']
encodeCols(columns)

# %%
df_clean['Brand'].unique()
# Out:
# array([11, 17, 23, 24, 28,  8,  4, 27,  3, 29, 10,  2, 18, 14, 12,  7, 30,
#        26,  6,  0, 25, 15, 19, 21, 20,  5, 13,  9, 16, 22,  1])

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1020 non-null   int64
#  1   Name                 1020 non-null   int32
#  2   Brand                1020 non-null   int32
#  3   Price                1020 non-null   int64
#  4   Processor_brand      1020 non-null   int32
#  5   Processor_name       1020 non-null   int32
#  6   Processor_variant    1020 non-null   int32
#  7   Processor_gen        1020 non-null   int64
#  8   RAM_GB               1020 non-null   int64
#  9   RAM_type             1020 non-null   int32
#  10  Storage_capacity_GB  1020 non-null   int64
#  11  Storage_type         1020 non-null   int32
#  12  Graphics_name        1020 non-null   int32
#  13  Graphics_brand       1020 non-null   int32
#  14  Graphics_GB          1020 non-null   int64
# ...

# %%
df_clean.to_csv(r'cleaned-data.csv', index= False, header = True)

# %%
df_clean.head(2)
# Out:
#    Unnamed: 0  Name  Brand  Price  Processor_brand  Processor_name  \
# 0           0   580     11  50399                0               4
# 1           1   837     17  26690                0               3
#
#    Processor_variant  Processor_gen  RAM_GB  RAM_type  Storage_capacity_GB  \
# 0                 74              5       8         1                  512
# 1                 87              7       8         7                  512
#
#    Storage_type  Graphics_name  Graphics_brand  Graphics_GB  \
# 0             2             22               0            4
# 1             2             19               0            5
#
#    Display_size_inches  Touch_screen  Operating_system
# 0                   15             1                11
# 1                   15             0                11

# %% [markdown]
# # Data Splitting / Train-Test Split

# %%
X = df_clean.drop(columns=["Name", "Price"])
Y = df_clean["Price"]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("Training set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Training set size: (816, 16)
# Test set size: (204, 16)

# %% [markdown]
# # Training / Applying Classifier / Accuracy:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"R² Score (Accuracy): {r2:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R² Score (Accuracy): 0.78
# Mean Absolute Error: 19588.39
